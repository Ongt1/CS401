# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import random, cmath, math
# from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, assemble, Aer
# from qiskit.quantum_info import Statevector
# from qiskit.visualization import array_to_latex, state_visualization
# from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_city 
# import qis401

# %%
pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (0.42.1)
# Requirement already satisfied: qiskit-terra==0.23.3 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit) (0.23.3)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit) (0.20.2)
# Requirement already satisfied: qiskit-aer==0.12.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit) (0.12.0)
# Requirement already satisfied: rustworkx>=0.12.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (0.12.1)
# Requirement already satisfied: sympy>=1.3 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (1.11.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (5.0.0)
# Requirement already satisfied: symengine>=0.9; platform_machine == "x86_64" or platform_machine == "aarch64" or platform_machine == "ppc64le" or platform_machine == "amd64" or platform_machine == "arm64" in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (1.24.3)
# Requirement already satisfied: psutil>=5 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (5.9.5)
# Requirement already satisfied: ply>=3.10 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (3.11)
# Requirement already satisfied: scipy>=1.5 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (1.10.1)
# Requirement already satisfied: dill>=0.3 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-terra==0.23.3->qiskit) (0.3.6)
# Requirement already satisfied: requests>=2.19 in /usr/lib/python3/dist-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.22.0)
# Requirement already satisfied: websockets>=10.0; python_version >= "3.7" in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (11.0.2)
# Requirement already satisfied: requests-ntlm<=1.1.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/lib/python3/dist-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.25.8)
# Requirement already satisfied: websocket-client>=1.5.1 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.5.1)
# Requirement already satisfied: mpmath>=0.19 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.23.3->qiskit) (1.3.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from stevedore>=3.0.0->qiskit-terra==0.23.3->qiskit) (5.11.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.0->qiskit-terra==0.23.3->qiskit) (1.14.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/lib/python3/dist-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (2.8)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /Volumes/Users/ong_t1/.local/lib/python3.8/site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Qiskit and NumPy imports
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, assemble, Aer, BasicAer, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex
from qiskit.visualization import state_visualization
from qiskit.visualization import plot_state_city, plot_bloch_multivector, plot_histogram
import random, math, cmath 
import qis401

# %%
three_color_matrix = [[0, 1/math.sqrt(3), 1/math.sqrt(3), 1/math.sqrt(3)], [1/math.sqrt(3), 2/3, -1/3, -1/3], [1/math.sqrt(3), -1/3, 2/3, -1/3], [1/math.sqrt(3), -1/3, -1/3, 2/3]]

# %%
def quantum_xor_reversed(circ, a, b, result):
    ''' 
    Adds an XOR gate to circuit circ, that computes a XOR b and stores the result on result.
    Five additional ancillas are included to store intermediate results. 
    '''
    circ.barrier()
    circ.cx(b, result)
    circ.cx(a, result)
    circ.barrier()

# %%
def initialize_3coloring_grovers_circuit(n, m):
    """
    Initializes the initial circuit for 3-coloring problem 

    Args:
      n: the number of variables of 3-coloring problem 
      m: the number of edges connecting n variables
    @return the 6-tuple, including Quantum circuit, quantum registers of each variable, quantum registers of edges.
    """
    # create circuit registers
    x_reg = QuantumRegister(2*n, "x_reg")
    edges_ancilla = QuantumRegister(2*m, "clause_ancilla")
    edges_outputs = QuantumRegister(m, "edges_register")
    y_reg = QuantumRegister(1, "y_reg")
    x_meas = ClassicalRegister(2*n, "x_meas")
    circ = QuantumCircuit(x_reg, edges_ancilla, edges_outputs, y_reg, x_meas)

    # set up edge outputs to be start in state|1>
    circ.x(edges_outputs)
    circ.x(y_reg)
    circ.h(y_reg)


    for i in range(0, 2*n, 2):
        circ.unitary(three_color_matrix, [x_reg[i], x_reg[i+1]])

    return circ, x_reg, edges_ancilla, edges_outputs, y_reg, x_meas


def quantum_xor(circ, a, b, result):
    ''' 
    Adds an XOR gate to circuit circ, that computes a XOR b and stores the result on result.
    Five additional ancillas are included to store intermediate results. 
    '''
    circ.barrier()
    circ.cx(a, result)
    circ.cx(b, result)
    circ.barrier()


def quantum_or_simplified(circ, a, b, result):
    '''
    Adds an OR gate to a quantum circuit.
    
    Args:
        QuantumRegisters a, b, and result (result is in state |1>)
    @return:
        a OR b is stored on result. a and b contain original values
    '''
    # apply OR = (NOT a) NAND (NOT b)
    circ.x(a)
    circ.x(b) 

    circ.ccx(a, b, result)
    
    # restore values of a and b 
    circ.x(a)
    circ.x(b) 


def add_clause(circ, vars_reg, edge, c_index, edges_ancilla, edges_outputs):
    """
    Adds XOR gates, OR gate to a quantum circuit

    Args:
      QuantumRegisters a,b, and result (result is in state |1>)
    @return 
      a OR b is stored on result.
    """
    vertex1 = edge[0] - 1
    vertex2 = edge[1] - 1

    # perform the XOR operations in the edge, then perform the OR operation on the two vertices on the edge.
    quantum_xor(circ, vars_reg[2*vertex1], vars_reg[2*vertex2], edges_ancilla[2*c_index])

    quantum_xor(circ, vars_reg[2*vertex1+1], vars_reg[2*vertex2+1], edges_ancilla[2*c_index+1])

    quantum_or_simplified(circ, edges_ancilla[2*c_index], edges_ancilla[2*c_index+1], edges_outputs[c_index])


def add_clause_reverse(circ, vars_reg, edge, c_index, edges_ancilla, edges_outputs):
    """
    Adds XOR-reversed gates, OR-reversed gate to a quantum circuit

    Args:
      QuantumRegisters a,b, and result (result is in state |1>)
    """
    vertex1 = edge[0] - 1
    vertex2 = edge[1] - 1
    
    # reset the circuit after performing the operations on the edge
    quantum_or_simplified(circ, edges_ancilla[2*c_index], edges_ancilla[2*c_index+1], edges_outputs[c_index])

    quantum_xor_reversed(circ, vars_reg[2*vertex1+1], vars_reg[2*vertex2+1], edges_ancilla[2*c_index+1])

    quantum_xor_reversed(circ, vars_reg[2*vertex1], vars_reg[2*vertex2], edges_ancilla[2*c_index])


def add_3color_oracle(circ, edges, x_reg, edges_ancilla, edges_outputs, y_reg):
    """
    Implements XOR, OR operations to a quantum circuit and verifies 3-coloring instance

    Args:
    Quantum circuit after initializing
      edges: list of tuples of two vertices
 
    """

    # add clause sub-circuits
    for c in range(len(edges)):
        edge = edges[c]
        add_clause(circ, x_reg, edge, c, edges_ancilla, edges_outputs)

    # check if all edges are satisfied
    circ.mct(edges_outputs, y_reg)

    # reset the circuit
    for c in range(len(edges)-1, -1, -1):
        edge = edges[c]
        add_clause_reverse(circ, x_reg, edge, c, edges_ancilla, edges_outputs)


def add_diffuser(circ, vars_reg, n):
    for i in range(0, 2*n, 2):
        circ.unitary(three_color_matrix, [vars_reg[i], vars_reg[i+1]])

    matrix = np.identity(2**(2*n))
    for i in range(1, 2**(2*n)):
        matrix[i][i] = -1
    circ.unitary(matrix, vars_reg)

    for i in range(0, 2*n, 2):
        circ.unitary(three_color_matrix, [vars_reg[i], vars_reg[i+1]])


def three_coloring_grovers(edges, n, trials):
    """
    Constructs the
    """
    N = int(math.sqrt(2**n))
    circ, x_reg, edges_ancilla, edges_outputs, y_reg, x_meas = initialize_3coloring_grovers_circuit(n, len(edges))
    for j in range(N):
        add_3color_oracle(circ, edges, x_reg, edges_ancilla, edges_outputs, y_reg)
        add_diffuser(circ, x_reg, n)

    circ.measure(x_reg, x_meas)
    result = qis401.simulate_circuit(circ, shots=trials)
    counts = result.get_counts(circ)
    return counts

# %%
# testing
edges = [(2,3), (1,2)]
n = 3
trials = 500
counts = three_coloring_grovers(edges, n, trials)
plot_histogram(counts)

# %%
# testing
edges = [(1,2), (2,3), (1,3)]
n = 3
trials = 800
counts = three_coloring_grovers(edges, n, trials)
plot_histogram(counts)

# %%
# testing
edges = [(1,2), (2,3), (1,4)]
n = 4
trials = 1600
counts = three_coloring_grovers(edges, n, trials)
plot_histogram(counts)

# %%
# # testing
# edges = [(1,2), (2,3), (3,4)]
# n = 4
# trials = 1600
# counts = three_coloring_grovers(edges, n, trials)
# plot_histogram(counts)
